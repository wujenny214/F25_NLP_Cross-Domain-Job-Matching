# %%
import pandas as pd

## Raw dataset
data= pd.read_csv("../raw_dataset/resumes.csv")

# %%
resume_df=data[[
    "Uniq Id",
    "Work Experience", "Education", "Skills", 
    "Additional Information"
]]
resume_df
# Out:
#                             Uniq Id  \
# 0  3ddb29e616f31947053b257f327969d7
# 1  9138476c76bcbbefadedd4862966c3d2
# 2  cd1cafa706f917a627982bf47291b888
# 3  53aea69598c6c1084e4bce89f0494bc3
# 4  90f8f99d66ebc6c09fceee37aff14bc1
# 5  fb1c760fd5311dad01e950f3062a9296
# 6  7795cdc183ab88aaffec73a5d99a1b82
# 7  e219a144eca8463f5d70fdec9426466f
# 8  c7c409fe9652e1eae9ecb05cce05426e
# 9  7f562eaaa992790efe423a197bfd0ffa
#
#                                      Work Experience  \
# 0  Sales Manager-MadgeTech, Inc-August 2015 to Fe...
# 1  Implementation Engineer-Versatile Communicatio...
# 2  Education Information Dissemination Coordinato...
# 3  Engineering Department Intern-Town of Billeric...
# 4  Pack and Ship/SORT Technician-Intel Corporatio...
# 5  BDC Data Analyst-Gary Rome Auto Group-January ...
# 6  Safety Engineer Intern-Hexagon Manufacturing I...
# 7  Classified Ads Manager-Quality of Life Publica...
# 8  ASSISTANT PROGRAM MANAGER-HARBOR HOMES-August ...
# ...
