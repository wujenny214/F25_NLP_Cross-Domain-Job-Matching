# %% [markdown]
# ## Dataset Embedding Experiments with SBERT and fine tuned cross encoder

# %%
import pandas as pd
import json
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
from sentence_transformers import SentenceTransformer
bi_encoder = SentenceTransformer('all-mpnet-base-v2')

# %%
jd_df = pd.read_excel("../1_data_cleaning/filtered_jd_sections2.xlsx")
jd_df.head()
# Out:
#                                      job_description location_cleaned  \
# 0  Job SummaryDo you have a strong aptitude for w...       Natick, MA
# 1  Overview External: Chevron is one of the world...      Houston, TX
# 2  Overview: The Hartman Non-Profit is seeking to...      Houston, TX
# 3  City: Houston State:Texas Postal/Zip Code: 770...      Houston, TX
# 4  Hiring! Immediate openings for Customer Suppor...  San Antonio, TX
#
#                                       job_title  \
# 0  Content Developer for MATLAB Code Generation
# 1                                Land Assistant
# 2                         Development Associate
# 3      Asphalt Quality Control Manager -Houston
# 4                  Customer Support Specialist!
#
#                                            jd_duties  \
# 0  Software components make up an ever larger par...
# 1  Overview External: Chevron is one of the world...
# 2  Overview: The Hartman Non-Profit is seeking to...
# 3  Our operations span the nation from Montana to...
# 4  Immediate openings for Customer Support Specia...
#
#                                      jd_requirements  \
# 0  Job SummaryDo you have a strong aptitude for w...
# 1  Prepare, and secure appropriate approvals for ...
# 2  Required Abilities and Experience: · A strong ...
# 3  Other Requirements Display a professional and ...
# 4  Hiring\nWe want your excellent customer servic...
#
#                                         jd_education
# 0  Minimum Qualifications A bachelor's degree and...
# 1        Preferred Qualifications: Bachelor's degree
# 2  · A minimum of a Bachelor’s degree in a busine...
# 3                Qualifications Bachelor’s degree (B
# 4                            High School Diploma/GED

# %%
# create semantic sentence for each row
def jd_build_semantic_sentence(row):
    desc = str(row.get("job_description", ""))
    duties = str(row.get("jd_duties", ""))
    req = str(row.get("jd_requirements", ""))
    edu = str(row.get("jd_education", ""))
    title = str(row.get("job_title", ""))

    return (
        f"Job Posting:\n"
        f"- Job Title: {title}\n"
        f"- Description: {desc}\n"
        f"- Responsibilities: {duties}\n"
        f"- Requirements: {req}\n"
        f"- Preferred Education: {edu}"
    )



jd_df["semantic_sentence"] = jd_df.apply(jd_build_semantic_sentence, axis=1)
jd_df.head()
# Out:
#                                      job_description location_cleaned  \
# 0  Job SummaryDo you have a strong aptitude for w...       Natick, MA
# 1  Overview External: Chevron is one of the world...      Houston, TX
# 2  Overview: The Hartman Non-Profit is seeking to...      Houston, TX
# 3  City: Houston State:Texas Postal/Zip Code: 770...      Houston, TX
# 4  Hiring! Immediate openings for Customer Suppor...  San Antonio, TX
#
#                                       job_title  \
# 0  Content Developer for MATLAB Code Generation
# 1                                Land Assistant
# 2                         Development Associate
# 3      Asphalt Quality Control Manager -Houston
# 4                  Customer Support Specialist!
#
#                                            jd_duties  \
# 0  Software components make up an ever larger par...
# 1  Overview External: Chevron is one of the world...
# 2  Overview: The Hartman Non-Profit is seeking to...
# 3  Our operations span the nation from Montana to...
# 4  Immediate openings for Customer Support Specia...
#
#                                      jd_requirements  \
# 0  Job SummaryDo you have a strong aptitude for w...
# 1  Prepare, and secure appropriate approvals for ...
# 2  Required Abilities and Experience: · A strong ...
# 3  Other Requirements Display a professional and ...
# 4  Hiring\nWe want your excellent customer servic...
#
#                                         jd_education  \
# 0  Minimum Qualifications A bachelor's degree and...
# 1        Preferred Qualifications: Bachelor's degree
# 2  · A minimum of a Bachelor’s degree in a busine...
# 3                Qualifications Bachelor’s degree (B
# 4                            High School Diploma/GED
#
#                                    semantic_sentence
# 0  Job Posting:\n- Job Title: Content Developer f...
# 1  Job Posting:\n- Job Title: Land Assistant\n- D...
# 2  Job Posting:\n- Job Title: Development Associa...
# 3  Job Posting:\n- Job Title: Asphalt Quality Con...
# 4  Job Posting:\n- Job Title: Customer Support Sp...

# %%
resume_df = pd.read_csv("../1_data_cleaning/resume_cleaned_100.csv")
resume_df.head(10)
# Out:
#                                     career_objective  \
# 0  Experienced product development Engineer and m...
# 1  I am a software engineer, and I want to work o...
# 2  I desire to work for a company that provides c...
# 3  As a Data Analyst I always look into more inno...
# 4  Financial and Accounting professional with exp...
# 5  Fresher starting out with Business Analysis, a...
# 6  Data Scientist working on problems related to ...
# 7  Financial Accountant specializing in financial...
# 8  I am fresher data analyst starting out in ERP ...
# 9  Certified Data analyst with a degree in Electr...
#
#                                               skills  \
# 0  ['Microsoft Office', 'Microsoft Project', 'Pro...
# 1  ['C++', 'Python', 'Firebase', 'Flutter', 'Tens...
# 2  ['Word', 'SAP Time Approval', 'Excel', 'Travel...
# 3  ['Machine Learning', 'Artificial Intelligence'...
# 4  ['Power User of Microsoft Excel Epicor NetSuit...
# 5  ['Business Analyst', 'Data Analysis', 'Busines...
# 6  ['Java', 'C++', 'Python', 'Machine Learning', ...
# 7  ['account reconciliations', 'accounting', 'acc...
# 8  ['MIS reporting', 'Advanced Excel', 'Dashboard...
# 9  ['Python', 'Machine Learning', 'MySQL', 'Data ...
#
#                                         degree_names  \
# 0                            ['Bachelor of Science']
# 1                                         ['B.Tech']
# 2                              ['Associate of Arts']
# 3                               ['B.Tech', 'M.Tech']
# 4            ['Bachelor of Business Administration']
# 5                                            ['BBA']
# 6                               ['B.Tech', 'M.Tech']
# 7                        ['MBA', 'B.Com', 'Diploma']
# 8  ['B.A (Economics)', 'M.A (Economics), Correspo...
# 9                                    ['B.Tech/B.E.']
#
#                               major_field_of_studies  \
# 0                         ['Mechanical Engineering']
# 1                                      ['Computers']
# 2                      ['Administrative Assistance']
# 3                                       [None, None]
# 4                                     ['Accounting']
# 5                                            ['N/A']
# 6  ['Computer Science', 'Computer Science Enginee...
# 7  ['Finance and IT', 'Mgt Hons', 'Computer Appli...
# 8                         ['Economics', 'Economics']
# 9                  ['Electronics/Telecommunication']
#
#                                            positions  \
# 0  ['Engineering Manager', 'Project Engineer II',...
# 1                                            ['SDE']
# 2  ['ENGINEERING COORDINATOR', 'FACILITIES TEMP',...
# 3                                   ['Data Analyst']
# 4  ['Senior Accountant', 'Senior Accountant/Finan...
# 5                              ['Part-Time Analyst']
# 6                                 ['Data Scientist']
# 7                ['Accountant', 'Consultant', 'N/A']
# 8                                    ['MIS Analyst']
# 9                              ['Associate Analyst']
#
#                                     responsibilities
# 0  Management Trainee\nMechanical Systems\nMainte...
# 1  Recruitment Coordination\nAppointment Manageme...
# 2  Machine Learning Design\nData Analysis\nModel ...
# 3  Mikrotik Router Configuration\nOLT Device Setu...
# 4  Design Creation\nCAD Drawings\nDesign Optimiza...
# 5  Full Stack Development\nFront-end: ReactJS, Ne...
# 6  Machine Learning Design\nData Analysis\nModel ...
# 7  Machinery Maintenance\nTroubleshooting\nReport...
# 8  Management Trainee\nMechanical Systems\nMainte...
# 9  Project Design\nData Analysis\nACCORD/Alliance...

# %%
# create semantic sentences for resumes
def resume_build_semantic_sentence(row):
    def clean(value):
        if value is None:
            return ""
        if isinstance(value, list):
            return ", ".join([str(v) for v in value])
        return str(value).strip()

    career = clean(row.get("career_objective", ""))
    skills = clean(row.get("skills", ""))
    degrees = clean(row.get("degree_names", ""))
    majors = clean(row.get("major_field_of_studies", ""))
    work_exp = clean(row.get("responsibilities", ""))

    return (
        "Candidate Profile:\n"
        f"- Career Objective: {career}\n"
        f"- Work Experience: {work_exp}\n"
        f"- Skills: {skills}\n"
        f"- Degrees: {degrees}\n"
        f"- Major Field(s) of Study: {majors}"
    )

# %%
# create semantic sentences for resumes
resume_df["semantic_sentence"] = resume_df.apply(resume_build_semantic_sentence, axis=1)
resume_df.head()
# Out:
#                                     career_objective  \
# 0  Experienced product development Engineer and m...
# 1  I am a software engineer, and I want to work o...
# 2  I desire to work for a company that provides c...
# 3  As a Data Analyst I always look into more inno...
# 4  Financial and Accounting professional with exp...
#
#                                               skills  \
# 0  ['Microsoft Office', 'Microsoft Project', 'Pro...
# 1  ['C++', 'Python', 'Firebase', 'Flutter', 'Tens...
# 2  ['Word', 'SAP Time Approval', 'Excel', 'Travel...
# 3  ['Machine Learning', 'Artificial Intelligence'...
# 4  ['Power User of Microsoft Excel Epicor NetSuit...
#
#                               degree_names         major_field_of_studies  \
# 0                  ['Bachelor of Science']     ['Mechanical Engineering']
# 1                               ['B.Tech']                  ['Computers']
# 2                    ['Associate of Arts']  ['Administrative Assistance']
# 3                     ['B.Tech', 'M.Tech']                   [None, None]
# 4  ['Bachelor of Business Administration']                 ['Accounting']
#
#                                            positions  \
# 0  ['Engineering Manager', 'Project Engineer II',...
# 1                                            ['SDE']
# 2  ['ENGINEERING COORDINATOR', 'FACILITIES TEMP',...
# 3                                   ['Data Analyst']
# 4  ['Senior Accountant', 'Senior Accountant/Finan...
#
#                                     responsibilities  \
# 0  Management Trainee\nMechanical Systems\nMainte...
# 1  Recruitment Coordination\nAppointment Manageme...
# 2  Machine Learning Design\nData Analysis\nModel ...
# 3  Mikrotik Router Configuration\nOLT Device Setu...
# 4  Design Creation\nCAD Drawings\nDesign Optimiza...
#
#                                    semantic_sentence
# 0  Candidate Profile:\n- Career Objective: Experi...
# 1  Candidate Profile:\n- Career Objective: I am a...
# 2  Candidate Profile:\n- Career Objective: I desi...
# 3  Candidate Profile:\n- Career Objective: As a D...
# 4  Candidate Profile:\n- Career Objective: Financ...

# %%
# add index columns for both datasets
jd_df["jd_index"] = jd_df.index
resume_df["resume_index"] = resume_df.index

# %%
def embed_sentence(sentence):
    return bi_encoder.encode(sentence)

# %%
# embed JD semantic sentences
jd_df["semantic_emb"] = jd_df["semantic_sentence"].apply(embed_sentence)
jd_df.head()
# Out:
#                                      job_description location_cleaned  \
# 0  Job SummaryDo you have a strong aptitude for w...       Natick, MA
# 1  Overview External: Chevron is one of the world...      Houston, TX
# 2  Overview: The Hartman Non-Profit is seeking to...      Houston, TX
# 3  City: Houston State:Texas Postal/Zip Code: 770...      Houston, TX
# 4  Hiring! Immediate openings for Customer Suppor...  San Antonio, TX
#
#                                       job_title  \
# 0  Content Developer for MATLAB Code Generation
# 1                                Land Assistant
# 2                         Development Associate
# 3      Asphalt Quality Control Manager -Houston
# 4                  Customer Support Specialist!
#
#                                            jd_duties  \
# 0  Software components make up an ever larger par...
# 1  Overview External: Chevron is one of the world...
# 2  Overview: The Hartman Non-Profit is seeking to...
# 3  Our operations span the nation from Montana to...
# 4  Immediate openings for Customer Support Specia...
#
#                                      jd_requirements  \
# 0  Job SummaryDo you have a strong aptitude for w...
# 1  Prepare, and secure appropriate approvals for ...
# 2  Required Abilities and Experience: · A strong ...
# 3  Other Requirements Display a professional and ...
# 4  Hiring\nWe want your excellent customer servic...
#
#                                         jd_education  \
# 0  Minimum Qualifications A bachelor's degree and...
# 1        Preferred Qualifications: Bachelor's degree
# 2  · A minimum of a Bachelor’s degree in a busine...
# 3                Qualifications Bachelor’s degree (B
# 4                            High School Diploma/GED
#
#                                    semantic_sentence  jd_index  \
# 0  Job Posting:\n- Job Title: Content Developer f...         0
# 1  Job Posting:\n- Job Title: Land Assistant\n- D...         1
# 2  Job Posting:\n- Job Title: Development Associa...         2
# 3  Job Posting:\n- Job Title: Asphalt Quality Con...         3
# 4  Job Posting:\n- Job Title: Customer Support Sp...         4
#
#                                         semantic_emb
# 0  [-0.01010743, -0.023181727, -0.04194715, -0.05...
# 1  [0.0403891, 0.071830586, -0.001459733, -0.0418...
# 2  [0.03369266, 0.07779833, -0.009091425, 0.04633...
# 3  [-0.015358255, 0.04020661, -0.009223261, 0.023...
# 4  [0.018529262, -0.05091418, -0.046522737, -0.04...

# %%
# embed resume semantic sentences
resume_df["semantic_emb"] = resume_df["semantic_sentence"].apply(embed_sentence)
resume_df.head()
# Out:
#                                     career_objective  \
# 0  Experienced product development Engineer and m...
# 1  I am a software engineer, and I want to work o...
# 2  I desire to work for a company that provides c...
# 3  As a Data Analyst I always look into more inno...
# 4  Financial and Accounting professional with exp...
#
#                                               skills  \
# 0  ['Microsoft Office', 'Microsoft Project', 'Pro...
# 1  ['C++', 'Python', 'Firebase', 'Flutter', 'Tens...
# 2  ['Word', 'SAP Time Approval', 'Excel', 'Travel...
# 3  ['Machine Learning', 'Artificial Intelligence'...
# 4  ['Power User of Microsoft Excel Epicor NetSuit...
#
#                               degree_names         major_field_of_studies  \
# 0                  ['Bachelor of Science']     ['Mechanical Engineering']
# 1                               ['B.Tech']                  ['Computers']
# 2                    ['Associate of Arts']  ['Administrative Assistance']
# 3                     ['B.Tech', 'M.Tech']                   [None, None]
# 4  ['Bachelor of Business Administration']                 ['Accounting']
#
#                                            positions  \
# 0  ['Engineering Manager', 'Project Engineer II',...
# 1                                            ['SDE']
# 2  ['ENGINEERING COORDINATOR', 'FACILITIES TEMP',...
# 3                                   ['Data Analyst']
# 4  ['Senior Accountant', 'Senior Accountant/Finan...
#
#                                     responsibilities  \
# 0  Management Trainee\nMechanical Systems\nMainte...
# 1  Recruitment Coordination\nAppointment Manageme...
# 2  Machine Learning Design\nData Analysis\nModel ...
# 3  Mikrotik Router Configuration\nOLT Device Setu...
# 4  Design Creation\nCAD Drawings\nDesign Optimiza...
#
#                                    semantic_sentence  resume_index  \
# 0  Candidate Profile:\n- Career Objective: Experi...             0
# 1  Candidate Profile:\n- Career Objective: I am a...             1
# 2  Candidate Profile:\n- Career Objective: I desi...             2
# 3  Candidate Profile:\n- Career Objective: As a D...             3
# 4  Candidate Profile:\n- Career Objective: Financ...             4
#
#                                         semantic_emb
# 0  [0.012360605, -0.015497665, -0.039931927, -0.0...
# 1  [0.036700267, 0.0253673, -0.03069021, -0.05552...
# 2  [0.03119832, 0.022536693, -0.027450437, -0.057...
# 3  [0.023298906, 0.053408314, -0.053814877, -0.06...
# 4  [0.017975513, 0.055254415, -0.023993986, -0.05...

# %%
import numpy as np
from sklearn.preprocessing import normalize

jd_df["semantic_emb"] = list(normalize(np.vstack(jd_df["semantic_emb"]), axis=1))
resume_df["semantic_emb"] = list(normalize(np.vstack(resume_df["semantic_emb"]), axis=1))

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_coarse_candidates(resume_embedding, jd_df, top_k=50):
    # ensure JD embeddings form a clean 2D matrix
    jd_embs = np.vstack(jd_df["semantic_emb"].values)   

    # get cosine similarity scores
    sims = cosine_similarity(resume_embedding.reshape(1, -1), jd_embs)[0]

    # attach scores
    candidates = jd_df.copy()
    candidates["sim"] = sims

    # return top-k by cosine similarity
    return candidates.sort_values("sim", ascending=False).head(top_k)

# %%
import random
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)


def build_ce_ranking_data(resume_df, jd_df, bi_encoder, top_k=50):
    rows = []

    for idx, row in resume_df.iterrows():
        resume_sentence = row["semantic_sentence"]
        resume_emb = row["semantic_emb"]

        # coarse retrieve
        candidates = get_coarse_candidates(resume_emb, jd_df, top_k=top_k)

        # pos = rank 1
        pos_jd = candidates.iloc[0]["semantic_sentence"]

        # hard negatives (rank 1–10)
        hard_neg_pool = candidates.iloc[1:10]

        rows.append({
            "resume": resume_sentence,
            "jd": pos_jd,
            "label": 1.0
        })

        for _, neg_row in hard_neg_pool.iterrows():
            neg_jd = neg_row["semantic_sentence"]
            rows.append({
                "resume": resume_sentence,
                "jd": neg_jd,
                "label": 0.0
            })

    return pd.DataFrame(rows)


training_df = build_ce_ranking_data(resume_df, jd_df, bi_encoder)

training_df.head()
# Out:
#                                               resume  \
# 0  Candidate Profile:\n- Career Objective: Experi...
# 1  Candidate Profile:\n- Career Objective: Experi...
# 2  Candidate Profile:\n- Career Objective: Experi...
# 3  Candidate Profile:\n- Career Objective: Experi...
# 4  Candidate Profile:\n- Career Objective: Experi...
#
#                                                   jd  label
# 0  Job Posting:\n- Job Title: Sr. Project Enginee...    1.0
# 1  Job Posting:\n- Job Title: Product Manager\n- ...    0.0
# 2  Job Posting:\n- Job Title: Project Manager\n- ...    0.0
# 3  Job Posting:\n- Job Title: Mechanical Engineer...    0.0
# 4  Job Posting:\n- Job Title: Project Manager\n- ...    0.0

# %%
from sentence_transformers import InputExample

train_samples = []
for idx, row in training_df.iterrows():
    train_samples.append(
        InputExample(
            texts=[row["resume"], row["jd"]],
            label=float(row["label"])
        )
    )

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(train_samples, shuffle=True, batch_size=8)

# %%
from sentence_transformers import CrossEncoder
from transformers import AutoTokenizer
import torch.nn as nn


model = CrossEncoder(
    'cross-encoder/ms-marco-MiniLM-L-12-v2',
    num_labels=1,
    activation_fn=nn.Sigmoid(),
)

model.fit(
    train_dataloader=train_dataloader,
    epochs=5,
    warmup_steps=50,
    optimizer_params={'lr': 2e-5}
)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (805 > 512). Running this sequence through the model will result in indexing errors
# /opt/miniconda3/envs/jobmatch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='625' max='625' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [625/625 03:47, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.332100</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
model.save("./finetuned_ce_model")

# %%
cross_encoder = CrossEncoder('./finetuned_ce_model')

# %%
def rerank_with_cross_encoder(resume_sentence, candidate_df, cross_encoder, top_k=3):
    if candidate_df is None or len(candidate_df) == 0:
        return []

    pairs = [(resume_sentence, jd_sent) for jd_sent in candidate_df["semantic_sentence"]]
    scores = cross_encoder.predict(pairs)

    candidate_df = candidate_df.copy()
    candidate_df["ce_score"] = scores  # keep raw CE score

    top_matches = (
    candidate_df.sort_values("ce_score", ascending=False)
                .reset_index(drop=True)
                .head(top_k)
)

    return top_matches

# %%
def match_resume(resume_row, jd_df, k_coarse=50, k_final=3):
    resume_emb = np.array(resume_row["semantic_emb"])
    resume_sentence = resume_row["semantic_sentence"]

    # coarse retrieve with cosine similarity
    candidates = get_coarse_candidates(
        resume_embedding=resume_emb,
        jd_df=jd_df,
        top_k=k_coarse
    )

    # cross encoder rerank
    final_matches = rerank_with_cross_encoder(
        resume_sentence=resume_sentence,
        candidate_df=candidates,
        cross_encoder=cross_encoder,
        top_k=k_final
    )

    # compute REAL cosine similarity for the CE-selected top-k
    result_rows = []
    resume_tensor = resume_row["semantic_emb"]

    for _, row in final_matches.iterrows():
        jd_emb = row["semantic_emb"]
        cos_sim = cosine_similarity([resume_tensor], [jd_emb])[0][0]

        result_rows.append({
            "jd_index": row["jd_index"],
            "job_title": row["job_title"],
            "location_cleaned": row["location_cleaned"],
            "similarity": cos_sim      
        })

    return result_rows

# %%
for i in range(len(resume_df)):
    row = resume_df.iloc[i]
    top_matches = match_resume(row, jd_df)

    print(f"================ Resume #{i} ================")
    print(row["responsibilities"][:400], "...\n")
    print(top_matches)
    print("-----------------------------------------------------\n")
# Out:
# ================ Resume #0 ================
# Management Trainee
# Mechanical Systems
# Maintenance & Troubleshooting
# Performance Analysis
# Project Support
# Process Improvement
# Training & Development
# Administrative Support ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.79016834)}, {'jd_index': 887, 'job_title': 'Product Manager', 'location_cleaned': 'Boston, MA', 'similarity': np.float32(0.68856347)}, {'jd_index': 878, 'job_title': 'Product Analyst', 'location_cleaned': 'Boston, MA', 'similarity': np.float32(0.67432046)}]
# -----------------------------------------------------
#
# ================ Resume #1 ================
# Recruitment Coordination
# Appointment Management
# Selection Criteria
# Employee Orientation
# Performance Evaluation
# HR Database Management
# Report Compilation
# Documentation
# Event Coordination
# Task Execution ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6963854)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.66713023)}, {'jd_index': 395, 'job_title': 'Software Engineer L (Government)', 'location_cleaned': 'Columbia, MD', 'similarity': np.float32(0.59479415)}]
# -----------------------------------------------------
#
# ================ Resume #2 ================
# Machine Learning Design
# Data Analysis
# Model Training
# AI Integration
# Innovation
# Cross-Functional Collaboration
# Model Deployment
# Documentation
# Analytical Skills
# Communication
# Team Collaboration ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6934099)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6043573)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.67708164)}]
# -----------------------------------------------------
#
# ================ Resume #3 ================
# Mikrotik Router Configuration
# OLT Device Setup & Management
# Integration with Billing Software
# Network Monitoring Tools Integration
# Connectivity Troubleshooting
# Technical Support & Escalation
# Installation & Configuration
# GPON/EPON Expertise
# Cisco, OLT, MikroTik Knowledge ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6990347)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.68559015)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6575532)}]
# -----------------------------------------------------
#
# ================ Resume #4 ================
# Design Creation
# CAD Drawings
# Design Optimization
# Team Collaboration
# Compliance Assurance
# Design Reviews
# Manufacturing Support
# Documentation ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.67685026)}, {'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.73274815)}, {'jd_index': 21, 'job_title': 'Payroll Analyst', 'location_cleaned': 'Portland, OR', 'similarity': np.float32(0.67729706)}]
# -----------------------------------------------------
#
# ================ Resume #5 ================
# Full Stack Development
# Front-end: ReactJS, NextJS
# Backend: Python, Django
# API Design
# Server-Side Logic
# DRF (Django REST Framework)
# Database Management (PostgreSQL, MySQL)
# Version Control (Git)
# AWS (ECR, RDS, ECS, ALB, EC2, etc.)
# Linux, Docker, CI/CD, GitLab
# Terraform, Shell Scripting ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.68679535)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.6345831)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6320911)}]
# -----------------------------------------------------
#
# ================ Resume #6 ================
# Machine Learning Design
# Data Analysis
# Model Training
# AI Integration
# Innovation
# Cross-Functional Collaboration
# Model Deployment
# Documentation
# Analytical Skills
# Communication
# Team Collaboration ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6552638)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.7317828)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.6503327)}]
# -----------------------------------------------------
#
# ================ Resume #7 ================
# Machinery Maintenance
# Troubleshooting
# Report Preparation
# Log Maintenance ...
#
# [{'jd_index': 238, 'job_title': 'AVP Finance', 'location_cleaned': 'Kettering, OH', 'similarity': np.float32(0.75826997)}, {'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.6952131)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.5940909)}]
# -----------------------------------------------------
#
# ================ Resume #8 ================
# Management Trainee
# Mechanical Systems
# Maintenance & Troubleshooting
# Performance Analysis
# Project Support
# Process Improvement
# Training & Development
# Administrative Support ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.66785765)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.69468236)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.67786324)}]
# -----------------------------------------------------
#
# ================ Resume #9 ================
# Project Design
# Data Analysis
# ACCORD/Alliance Knowledge
# BNBC Standards
# Cost Estimation
# Feasibility Studies
# Documentation
# Compliance
# Site Monitoring
# Policy Enforcement
# Legal Compliance
# Data Management
# Team Collaboration ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.65921915)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.70970255)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.681593)}]
# -----------------------------------------------------
#
# ================ Resume #10 ================
# Apparel Sourcing
# Quality Garment Sourcing
# Reliable Partner
# Buyer/Vendor Communication ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.66073835)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.686087)}, {'jd_index': 240, 'job_title': '.Net Developer', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.7023943)}]
# -----------------------------------------------------
#
# ================ Resume #11 ================
# Application Development
# Object-Oriented Design
# Collaboration
# Problem-Solving
# Software Lifecycle
# Innovation
# Software Testing
# System Analysis
# Performance Monitoring
# Plugin Development
# Documentation
# Integration Support ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.71390605)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6212095)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6876708)}]
# -----------------------------------------------------
#
# ================ Resume #12 ================
# Design Review
# Coordination
# Proposal Preparation
# Feasibility Analysis
# Software Utilization
# Supervision
# Technical Support
# Submission Review
# Progress Reporting
# Compliance
# Site Visits ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.65127003)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.71968496)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.6941208)}]
# -----------------------------------------------------
#
# ================ Resume #13 ================
# Hardware & Network Installation
# Troubleshooting & Diagnostics
# User Training & Capacity Building
# Hardware Replacement
# Fault Repair & System Setup
# Software License & Account Management
# Backup Management
# System Updates & Maintenance
# Server & Storage Management
# Documentation & Technical Specifications
# Data Protection & Disaster Recovery
# Storage & Database Planning
# Power & Disk Backup
# Incident Manageme ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6915355)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.7091356)}, {'jd_index': 369, 'job_title': 'Senior Network Engineer (Government)', 'location_cleaned': 'Columbia, MD', 'similarity': np.float32(0.72592103)}]
# -----------------------------------------------------
#
# ================ Resume #14 ================
# Database Design & Development
# SQL Query Optimization
# Data Integrity & Security
# BI Solutions Development
# ETL Process Implementation
# Database Maintenance
# Backup & Restore Management
# Index Rebuilding & Performance Tuning
# SQL Server Clustering & High Availability
# SQL Server Replication
# High Availability Group Management
# Database Monitoring & Troubleshooting ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6153777)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6620661)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6017542)}]
# -----------------------------------------------------
#
# ================ Resume #15 ================
# Generative AI Development
# Evolutionary Computation
# Deep Learning Optimization
# Expert Systems Design
# Knowledge Representation
# Data Preprocessing
# Model Training
# Research & Integration ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.72277904)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6635386)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6521901)}]
# -----------------------------------------------------
#
# ================ Resume #16 ================
# Application Development
# Object-Oriented Design
# Collaboration
# Problem-Solving
# Software Lifecycle
# Innovation
# Software Testing
# System Analysis
# Performance Monitoring
# Plugin Development
# Documentation
# Integration Support ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.71749985)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.69795734)}, {'jd_index': 369, 'job_title': 'Senior Network Engineer (Government)', 'location_cleaned': 'Columbia, MD', 'similarity': np.float32(0.68886375)}]
# -----------------------------------------------------
#
# ================ Resume #17 ================
# Data Platform Design
# Data Pipeline Development
# ETL Processes
# SQL Query Optimization
# Data Integration & Transformation
# Data Modeling
# Stakeholder Collaboration
# Data Quality Monitoring
# Continuous Learning ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6662251)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.61523414)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.630137)}]
# -----------------------------------------------------
#
# ================ Resume #18 ================
# Data Platform Design
# Data Pipeline Development
# ETL Processes
# SQL Query Optimization
# Data Integration & Transformation
# Data Modeling
# Stakeholder Collaboration
# Data Quality Monitoring
# Continuous Learning ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.66826487)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6275101)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6337424)}]
# -----------------------------------------------------
#
# ================ Resume #19 ================
# Database Design & Development
# SQL Query Optimization
# Data Integrity & Security
# BI Solutions Development
# ETL Process Implementation
# Database Maintenance
# Backup & Restore Management
# Index Rebuilding & Performance Tuning
# SQL Server Clustering & High Availability
# SQL Server Replication
# High Availability Group Management
# Database Monitoring & Troubleshooting ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6484655)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6931179)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.6894911)}]
# -----------------------------------------------------
#
# ================ Resume #20 ================
# Database Design & Development
# SQL Query Optimization
# Data Integrity & Security
# BI Solutions Development
# ETL Process Implementation
# Database Maintenance
# Backup & Restore Management
# Index Rebuilding & Performance Tuning
# SQL Server Clustering & High Availability
# SQL Server Replication
# High Availability Group Management
# Database Monitoring & Troubleshooting ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6475316)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.7374582)}, {'jd_index': 987, 'job_title': 'Database Architect', 'location_cleaned': 'Dallas, TX', 'similarity': np.float32(0.6700377)}]
# -----------------------------------------------------
#
# ================ Resume #21 ================
# Recruitment Coordination
# Appointment Management
# Selection Criteria
# Employee Orientation
# Performance Evaluation
# HR Database Management
# Report Compilation
# Documentation
# Event Coordination
# Task Execution ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.69880176)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.65801704)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6115712)}]
# -----------------------------------------------------
#
# ================ Resume #22 ================
# Data Platform Design
# Data Pipeline Development
# ETL Processes
# SQL Query Optimization
# Data Integration & Transformation
# Data Modeling
# Stakeholder Collaboration
# Data Quality Monitoring
# Continuous Learning ...
#
# [{'jd_index': 238, 'job_title': 'AVP Finance', 'location_cleaned': 'Kettering, OH', 'similarity': np.float32(0.7651742)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.59823203)}, {'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.70184445)}]
# -----------------------------------------------------
#
# ================ Resume #23 ================
# Design Review
# Coordination
# Proposal Preparation
# Feasibility Analysis
# Software Utilization
# Supervision
# Technical Support
# Submission Review
# Progress Reporting
# Compliance
# Site Visits ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.68129885)}, {'jd_index': 700, 'job_title': 'ENTRY LEVEL TEAM LEADER / TEAM MANAGER', 'location_cleaned': 'Hendersonville, TN', 'similarity': np.float32(0.7160466)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.66018426)}]
# -----------------------------------------------------
#
# ================ Resume #24 ================
# Data Platform Design
# Data Pipeline Development
# ETL Processes
# SQL Query Optimization
# Data Integration & Transformation
# Data Modeling
# Stakeholder Collaboration
# Data Quality Monitoring
# Continuous Learning ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.80725884)}, {'jd_index': 874, 'job_title': 'Production Supervisor', 'location_cleaned': 'Kenosha, WI', 'similarity': np.float32(0.73402643)}, {'jd_index': 700, 'job_title': 'ENTRY LEVEL TEAM LEADER / TEAM MANAGER', 'location_cleaned': 'Hendersonville, TN', 'similarity': np.float32(0.7135265)}]
# -----------------------------------------------------
#
# ================ Resume #25 ================
# 15+ Years Banking Experience
# Audit/Inspection/ICC Leadership
# Internal Audit & Compliance
# Risk-Based Operational Reviews
# System-Based Audit Expertise
# Knowledge of Bangladeshi Laws ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.63849354)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.62928843)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.6759165)}]
# -----------------------------------------------------
#
# ================ Resume #26 ================
# Project Design
# Data Analysis
# ACCORD/Alliance Knowledge
# BNBC Standards
# Cost Estimation
# Feasibility Studies
# Documentation
# Compliance
# Site Monitoring
# Policy Enforcement
# Legal Compliance
# Data Management
# Team Collaboration ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6666987)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.66324157)}, {'jd_index': 68, 'job_title': 'Data Architect', 'location_cleaned': 'Cary, NC', 'similarity': np.float32(0.68122566)}]
# -----------------------------------------------------
#
# ================ Resume #27 ================
# Data Platform Design
# Data Pipeline Development
# ETL Processes
# SQL Query Optimization
# Data Integration & Transformation
# Data Modeling
# Stakeholder Collaboration
# Data Quality Monitoring
# Continuous Learning ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.66307867)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6838794)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.67097723)}]
# -----------------------------------------------------
#
# ================ Resume #28 ================
# Open-Source Technologies
# CI/CD Culture & Tooling
# Product Availability & Scalability
# Automation (Build & Deploy)
# Monitoring & Reliability
# Infrastructure Innovation
# Software Engineering Velocity
# Infrastructure Resiliency
# Security & Data Availability ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6577496)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6711948)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.61190933)}]
# -----------------------------------------------------
#
# ================ Resume #29 ================
# Open-Source Technologies
# CI/CD Culture & Tooling
# Product Availability & Scalability
# Automation (Build & Deploy)
# Monitoring & Reliability
# Infrastructure Innovation
# Software Engineering Velocity
# Infrastructure Resiliency
# Security & Data Availability ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.67783344)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.636567)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.6470406)}]
# -----------------------------------------------------
#
# ================ Resume #30 ================
# Recruitment Coordination
# Appointment Management
# Selection Criteria
# Employee Orientation
# Performance Evaluation
# HR Database Management
# Report Compilation
# Documentation
# Event Coordination
# Task Execution ...
#
# [{'jd_index': 369, 'job_title': 'Senior Network Engineer (Government)', 'location_cleaned': 'Columbia, MD', 'similarity': np.float32(0.75767523)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.6898886)}, {'jd_index': 388, 'job_title': 'Software Engineer', 'location_cleaned': 'Columbia, MD', 'similarity': np.float32(0.6835481)}]
# -----------------------------------------------------
#
# ================ Resume #31 ================
# Generative AI Development
# Evolutionary Computation
# Deep Learning Optimization
# Expert Systems Design
# Knowledge Representation
# Data Preprocessing
# Model Training
# Research & Integration ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.712766)}, {'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.6799076)}, {'jd_index': 700, 'job_title': 'ENTRY LEVEL TEAM LEADER / TEAM MANAGER', 'location_cleaned': 'Hendersonville, TN', 'similarity': np.float32(0.73326266)}]
# -----------------------------------------------------
#
# ================ Resume #32 ================
# Open-Source Technologies
# CI/CD Culture & Tooling
# Product Availability & Scalability
# Automation (Build & Deploy)
# Monitoring & Reliability
# Infrastructure Innovation
# Software Engineering Velocity
# Infrastructure Resiliency
# Security & Data Availability ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.7171926)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.66282475)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.66261506)}]
# -----------------------------------------------------
#
# ================ Resume #33 ================
# Internal Audit Assistance
# Voucher & Bill Verification
# Cost Sheet Analysis
# L/C Voucher Verification
# Expense Verification
# Salary & Wages Verification
# Market Rate Verification ...
#
# [{'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.6255958)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.70705056)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.69796264)}]
# -----------------------------------------------------
#
# ================ Resume #34 ================
# Recruitment Coordination
# Appointment Management
# Selection Criteria
# Employee Orientation
# Performance Evaluation
# HR Database Management
# Report Compilation
# Documentation
# Event Coordination
# Task Execution ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.7058146)}, {'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.6030743)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.61461425)}]
# -----------------------------------------------------
#
# ================ Resume #35 ================
# Internal Audit Assistance
# Voucher & Bill Verification
# Cost Sheet Analysis
# L/C Voucher Verification
# Expense Verification
# Salary & Wages Verification
# Market Rate Verification ...
#
# [{'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.8069631)}, {'jd_index': 238, 'job_title': 'AVP Finance', 'location_cleaned': 'Kettering, OH', 'similarity': np.float32(0.7253343)}, {'jd_index': 21, 'job_title': 'Payroll Analyst', 'location_cleaned': 'Portland, OR', 'similarity': np.float32(0.6498186)}]
# -----------------------------------------------------
#
# ================ Resume #36 ================
# Project Design
# Data Analysis
# ACCORD/Alliance Knowledge
# BNBC Standards
# Cost Estimation
# Feasibility Studies
# Documentation
# Compliance
# Site Monitoring
# Policy Enforcement
# Legal Compliance
# Data Management
# Team Collaboration ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.7318728)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.72147644)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6735196)}]
# -----------------------------------------------------
#
# ================ Resume #37 ================
# Data Platform Design
# Data Pipeline Development
# ETL Processes
# SQL Query Optimization
# Data Integration & Transformation
# Data Modeling
# Stakeholder Collaboration
# Data Quality Monitoring
# Continuous Learning ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.68136925)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.64631784)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.58947)}]
# -----------------------------------------------------
#
# ================ Resume #38 ================
# Generative AI Development
# Evolutionary Computation
# Deep Learning Optimization
# Expert Systems Design
# Knowledge Representation
# Data Preprocessing
# Model Training
# Research & Integration ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6824211)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.604882)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.67255324)}]
# -----------------------------------------------------
#
# ================ Resume #39 ================
# Administrative Support
# Scheduling
# Filing & Documentation
# Communication
# Team Support
# Equipment Maintenance
# Information Provision
# Inventory Management
# Team Collaboration
# OHS Policy Development
# Safety Advice
# Risk Assessment
# Policy Review
# OHS Training
# Safety Inspections
# Unsafe Act Prevention
# Incident Investigation
# Report Preparation ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6110147)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6765791)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6833176)}]
# -----------------------------------------------------
#
# ================ Resume #40 ================
# 15+ Years Banking Experience
# Audit/Inspection/ICC Leadership
# Internal Audit & Compliance
# Risk-Based Operational Reviews
# System-Based Audit Expertise
# Knowledge of Bangladeshi Laws ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6394226)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.5675443)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.5486335)}]
# -----------------------------------------------------
#
# ================ Resume #41 ================
# Mikrotik Router Configuration
# OLT Device Setup & Management
# Integration with Billing Software
# Network Monitoring Tools Integration
# Connectivity Troubleshooting
# Technical Support & Escalation
# Installation & Configuration
# GPON/EPON Expertise
# Cisco, OLT, MikroTik Knowledge ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.68521065)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.69336104)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6452533)}]
# -----------------------------------------------------
#
# ================ Resume #42 ================
# Management Trainee
# Mechanical Systems
# Maintenance & Troubleshooting
# Performance Analysis
# Project Support
# Process Improvement
# Training & Development
# Administrative Support ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.68556166)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6027193)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6519721)}]
# -----------------------------------------------------
#
# ================ Resume #43 ================
# Full Stack Development
# Front-end: ReactJS, NextJS
# Backend: Python, Django
# API Design
# Server-Side Logic
# DRF (Django REST Framework)
# Database Management (PostgreSQL, MySQL)
# Version Control (Git)
# AWS (ECR, RDS, ECS, ALB, EC2, etc.)
# Linux, Docker, CI/CD, GitLab
# Terraform, Shell Scripting ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.7748902)}, {'jd_index': 887, 'job_title': 'Product Manager', 'location_cleaned': 'Boston, MA', 'similarity': np.float32(0.6743111)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.70537204)}]
# -----------------------------------------------------
#
# ================ Resume #44 ================
# Design Review
# Coordination
# Proposal Preparation
# Feasibility Analysis
# Software Utilization
# Supervision
# Technical Support
# Submission Review
# Progress Reporting
# Compliance
# Site Visits ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.63798857)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6380732)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.62117004)}]
# -----------------------------------------------------
#
# ================ Resume #45 ================
# Digital Marketing Strategy
# Brand Awareness, Online Traffic
# Social Media Management
# Google Analytics
# Cross-functional Teams
# Campaign Execution, SEO ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.7259631)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.63466454)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6568685)}]
# -----------------------------------------------------
#
# ================ Resume #46 ================
# Machine Learning Leadership
# Cross-Functional Collaboration
# Strategy Development
# ML/NLP Infrastructure
# Prototype Transformation
# ML System Design
# Algorithm Research
# Application Development
# Dataset Selection
# ML Testing
# Statistical Analysis
# R&D in ML/NLP
# Text Representation
# Data Pipeline Design
# Statistical Data Analysis
# Model Training
# Team Collaboration
# Research Reporting
# Algorithm Analysis ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.68631077)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.6328168)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6337892)}]
# -----------------------------------------------------
#
# ================ Resume #47 ================
# Design Creation
# CAD Drawings
# Design Optimization
# Team Collaboration
# Compliance Assurance
# Design Reviews
# Manufacturing Support
# Documentation ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6546501)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6663184)}, {'jd_index': 369, 'job_title': 'Senior Network Engineer (Government)', 'location_cleaned': 'Columbia, MD', 'similarity': np.float32(0.57916284)}]
# -----------------------------------------------------
#
# ================ Resume #48 ================
# 15+ Years Banking Experience
# Audit/Inspection/ICC Leadership
# Internal Audit & Compliance
# Risk-Based Operational Reviews
# System-Based Audit Expertise
# Knowledge of Bangladeshi Laws ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.62272424)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.7030608)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6585865)}]
# -----------------------------------------------------
#
# ================ Resume #49 ================
# Recruitment Coordination
# Appointment Management
# Selection Criteria
# Employee Orientation
# Performance Evaluation
# HR Database Management
# Report Compilation
# Documentation
# Event Coordination
# Task Execution ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.66565573)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6668879)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.612729)}]
# -----------------------------------------------------
#
# ================ Resume #50 ================
# Machine Learning Leadership
# Cross-Functional Collaboration
# Strategy Development
# ML/NLP Infrastructure
# Prototype Transformation
# ML System Design
# Algorithm Research
# Application Development
# Dataset Selection
# ML Testing
# Statistical Analysis
# R&D in ML/NLP
# Text Representation
# Data Pipeline Design
# Statistical Data Analysis
# Model Training
# Team Collaboration
# Research Reporting
# Algorithm Analysis ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6504555)}, {'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.621346)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.62319887)}]
# -----------------------------------------------------
#
# ================ Resume #51 ================
# Data Platform Design
# Data Pipeline Development
# ETL Processes
# SQL Query Optimization
# Data Integration & Transformation
# Data Modeling
# Stakeholder Collaboration
# Data Quality Monitoring
# Continuous Learning ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.64467937)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.71319)}, {'jd_index': 291, 'job_title': 'Growing Manufacturer seeking Metals Process Development Engineer', 'location_cleaned': 'Columbus, OH', 'similarity': np.float32(0.695575)}]
# -----------------------------------------------------
#
# ================ Resume #52 ================
# Internal Audit Assistance
# Voucher & Bill Verification
# Cost Sheet Analysis
# L/C Voucher Verification
# Expense Verification
# Salary & Wages Verification
# Market Rate Verification ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.68543947)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.641501)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6692938)}]
# -----------------------------------------------------
#
# ================ Resume #53 ================
# Digital Marketing Strategy
# Brand Awareness, Online Traffic
# Social Media Management
# Google Analytics
# Cross-functional Teams
# Campaign Execution, SEO ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6791798)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.65625083)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6259257)}]
# -----------------------------------------------------
#
# ================ Resume #54 ================
# Machinery Maintenance
# Troubleshooting
# Report Preparation
# Log Maintenance ...
#
# [{'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6245037)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.65404606)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.57394695)}]
# -----------------------------------------------------
#
# ================ Resume #55 ================
# Hardware & Network Installation
# Troubleshooting & Diagnostics
# User Training & Capacity Building
# Hardware Replacement
# Fault Repair & System Setup
# Software License & Account Management
# Backup Management
# System Updates & Maintenance
# Server & Storage Management
# Documentation & Technical Specifications
# Data Protection & Disaster Recovery
# Storage & Database Planning
# Power & Disk Backup
# Incident Manageme ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.7191838)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.6719289)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.64211404)}]
# -----------------------------------------------------
#
# ================ Resume #56 ================
# Full Stack Development
# Front-end: ReactJS, NextJS
# Backend: Python, Django
# API Design
# Server-Side Logic
# DRF (Django REST Framework)
# Database Management (PostgreSQL, MySQL)
# Version Control (Git)
# AWS (ECR, RDS, ECS, ALB, EC2, etc.)
# Linux, Docker, CI/CD, GitLab
# Terraform, Shell Scripting ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.6791606)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.74049115)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.69978374)}]
# -----------------------------------------------------
#
# ================ Resume #57 ================
# Trade Marketing Executive
# Brand Visibility, Sales Targets
# Field Marketing, Campaigns, Product Distribution
# Brand Head
# Excel, KPIs Tracking ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6491843)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.56466234)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6083225)}]
# -----------------------------------------------------
#
# ================ Resume #58 ================
# Generative AI Development
# Evolutionary Computation
# Deep Learning Optimization
# Expert Systems Design
# Knowledge Representation
# Data Preprocessing
# Model Training
# Research & Integration ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.6729547)}, {'jd_index': 700, 'job_title': 'ENTRY LEVEL TEAM LEADER / TEAM MANAGER', 'location_cleaned': 'Hendersonville, TN', 'similarity': np.float32(0.70235693)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.70991004)}]
# -----------------------------------------------------
#
# ================ Resume #59 ================
# Trade Marketing Executive
# Brand Visibility, Sales Targets
# Field Marketing, Campaigns, Product Distribution
# Brand Head
# Excel, KPIs Tracking ...
#
# [{'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.6692953)}, {'jd_index': 700, 'job_title': 'ENTRY LEVEL TEAM LEADER / TEAM MANAGER', 'location_cleaned': 'Hendersonville, TN', 'similarity': np.float32(0.730782)}, {'jd_index': 267, 'job_title': 'Level Help Desk', 'location_cleaned': 'Seattle, WA', 'similarity': np.float32(0.72029305)}]
# -----------------------------------------------------
#
# ================ Resume #60 ================
# Open-Source Technologies
# CI/CD Culture & Tooling
# Product Availability & Scalability
# Automation (Build & Deploy)
# Monitoring & Reliability
# Infrastructure Innovation
# Software Engineering Velocity
# Infrastructure Resiliency
# Security & Data Availability ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.5781024)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6083352)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.64305174)}]
# -----------------------------------------------------
#
# ================ Resume #61 ================
# Database Design & Development
# SQL Query Optimization
# Data Integrity & Security
# BI Solutions Development
# ETL Process Implementation
# Database Maintenance
# Backup & Restore Management
# Index Rebuilding & Performance Tuning
# SQL Server Clustering & High Availability
# SQL Server Replication
# High Availability Group Management
# Database Monitoring & Troubleshooting ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.68749094)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.7139535)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.7377663)}]
# -----------------------------------------------------
#
# ================ Resume #62 ================
# Design Review
# Coordination
# Proposal Preparation
# Feasibility Analysis
# Software Utilization
# Supervision
# Technical Support
# Submission Review
# Progress Reporting
# Compliance
# Site Visits ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.7375005)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.7013294)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.76030916)}]
# -----------------------------------------------------
#
# ================ Resume #63 ================
# 15+ Years Banking Experience
# Audit/Inspection/ICC Leadership
# Internal Audit & Compliance
# Risk-Based Operational Reviews
# System-Based Audit Expertise
# Knowledge of Bangladeshi Laws ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.70099616)}, {'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.60900116)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.66043115)}]
# -----------------------------------------------------
#
# ================ Resume #64 ================
# Machinery Maintenance
# Troubleshooting
# Report Preparation
# Log Maintenance ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.62072)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.63161975)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.5986477)}]
# -----------------------------------------------------
#
# ================ Resume #65 ================
# Mushak Forms Maintenance
# VAT Software & MS Office Maintenance
# VAT Ledger Management
# VAT Challan Coordination
# Liaison with VAT Office
# VAT Documentation
# Other Assigned Tasks ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.689139)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6453748)}, {'jd_index': 884, 'job_title': 'Scrum Master', 'location_cleaned': 'Framingham, MA', 'similarity': np.float32(0.5896071)}]
# -----------------------------------------------------
#
# ================ Resume #66 ================
# Machine Learning Leadership
# Cross-Functional Collaboration
# Strategy Development
# ML/NLP Infrastructure
# Prototype Transformation
# ML System Design
# Algorithm Research
# Application Development
# Dataset Selection
# ML Testing
# Statistical Analysis
# R&D in ML/NLP
# Text Representation
# Data Pipeline Design
# Statistical Data Analysis
# Model Training
# Team Collaboration
# Research Reporting
# Algorithm Analysis ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6493546)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6443606)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.5787936)}]
# -----------------------------------------------------
#
# ================ Resume #67 ================
# Open-Source Technologies
# CI/CD Culture & Tooling
# ...
# Cross-Team Collaboration
# Code Quality ...
#
# [{'jd_index': 369, 'job_title': 'Senior Network Engineer (Government)', 'location_cleaned': 'Columbia, MD', 'similarity': np.float32(0.60698295)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6298743)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.6380309)}]
# -----------------------------------------------------
#
# ================ Resume #78 ================
# Relationship Building
# HR Collaboration
# Policy Development
# Training Management
# Record Keeping
# Compliance
# Employee Development
# Policy Enforcement
# Communication
# Task Execution ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.7045121)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.59310335)}, {'jd_index': 884, 'job_title': 'Scrum Master', 'location_cleaned': 'Framingham, MA', 'similarity': np.float32(0.60071397)}]
# -----------------------------------------------------
#
# ================ Resume #79 ================
# Administrative Support
# Scheduling
# Filing & Documentation
# Communication
# Team Support
# Equipment Maintenance
# Information Provision
# Inventory Management
# Team Collaboration
# OHS Policy Development
# Safety Advice
# Risk Assessment
# Policy Review
# OHS Training
# Safety Inspections
# Unsafe Act Prevention
# Incident Investigation
# Report Preparation ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6075308)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.5644789)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.5625124)}]
# -----------------------------------------------------
#
# ================ Resume #80 ================
# Administrative Support
# Scheduling
# Filing & Documentation
# Communication
# Team Support
# Equipment Maintenance
# Information Provision
# Inventory Management
# Team Collaboration
# OHS Policy Development
# Safety Advice
# Risk Assessment
# Policy Review
# OHS Training
# Safety Inspections
# Unsafe Act Prevention
# Incident Investigation
# Report Preparation ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.7180156)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6617579)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6588195)}]
# -----------------------------------------------------
#
# ================ Resume #81 ================
# Administrative Support
# Scheduling
# Filing & Documentation
# Communication
# Team Support
# Equipment Maintenance
# Information Provision
# Inventory Management
# Team Collaboration
# OHS Policy Development
# Safety Advice
# Risk Assessment
# Policy Review
# OHS Training
# Safety Inspections
# Unsafe Act Prevention
# Incident Investigation
# Report Preparation ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.6390243)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.7084539)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.6862411)}]
# -----------------------------------------------------
#
# ================ Resume #82 ================
# Design Review
# Coordination
# Proposal Preparation
# Feasibility Analysis
# Software Utilization
# Supervision
# Technical Support
# Submission Review
# Progress Reporting
# Compliance
# Site Visits ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6964809)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.65051496)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.6724664)}]
# -----------------------------------------------------
#
# ================ Resume #83 ================
# Internal Audit Assistance
# Voucher & Bill Verification
# Cost Sheet Analysis
# L/C Voucher Verification
# Expense Verification
# Salary & Wages Verification
# Market Rate Verification ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.71534157)}, {'jd_index': 700, 'job_title': 'ENTRY LEVEL TEAM LEADER / TEAM MANAGER', 'location_cleaned': 'Hendersonville, TN', 'similarity': np.float32(0.76063776)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.67178684)}]
# -----------------------------------------------------
#
# ================ Resume #84 ================
# Open-Source Technologies
# CI/CD Culture & Tooling
# Product Availability & Scalability
# Automation (Build & Deploy)
# Monitoring & Reliability
# Infrastructure Innovation
# Software Engineering Velocity
# Infrastructure Resiliency
# Security & Data Availability ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.75949824)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.71715933)}, {'jd_index': 700, 'job_title': 'ENTRY LEVEL TEAM LEADER / TEAM MANAGER', 'location_cleaned': 'Hendersonville, TN', 'similarity': np.float32(0.6685093)}]
# -----------------------------------------------------
#
# ================ Resume #85 ================
# Generative AI Development
# Evolutionary Computation
# Deep Learning Optimization
# Expert Systems Design
# Knowledge Representation
# Data Preprocessing
# Model Training
# Research & Integration ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6876866)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6337435)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.6438956)}]
# -----------------------------------------------------
#
# ================ Resume #86 ================
# Design Creation
# CAD Drawings
# Design Optimization
# Team Collaboration
# Compliance Assurance
# Design Reviews
# Manufacturing Support
# Documentation ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.65096176)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.69746006)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6775999)}]
# -----------------------------------------------------
#
# ================ Resume #87 ================
# Machinery Maintenance
# Troubleshooting
# Report Preparation
# Log Maintenance ...
#
# [{'jd_index': 1159, 'job_title': 'Sr. Project Engineer', 'location_cleaned': 'State College, PA', 'similarity': np.float32(0.7439759)}, {'jd_index': 813, 'job_title': 'Software Engineer', 'location_cleaned': ' Laurel, NJ', 'similarity': np.float32(0.6775246)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.66857094)}]
# -----------------------------------------------------
#
# ================ Resume #88 ================
# Hardware & Software Installation
# System Monitoring
# IT Support
# Networking Expertise
# Mail Server Administration
# Security Management
# Troubleshooting & Repair
# Operations Support ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6226101)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.601316)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.58528113)}]
# -----------------------------------------------------
#
# ================ Resume #89 ================
# Data Platform Design
# Data Pipeline Development
# ETL Processes
# SQL Query Optimization
# Data Integration & Transformation
# Data Modeling
# Stakeholder Collaboration
# Data Quality Monitoring
# Continuous Learning ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6309838)}, {'jd_index': 65, 'job_title': 'IT - Systems Analysis Consultant - Senior', 'location_cleaned': 'Eden Prairie, MN', 'similarity': np.float32(0.6506559)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.64135116)}]
# -----------------------------------------------------
#
# ================ Resume #90 ================
# Technical Support
# Troubleshooting
# Collaboration
# Documentation
# System Monitoring
# Software Deployment
# Training & Mentorship
# Industry Trends
# Field Visits
#
#
#
#
#  ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.66235673)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.66796756)}, {'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.619102)}]
# -----------------------------------------------------
#
# ================ Resume #91 ================
# Design Creation
# CAD Drawings
# Design Optimization
# Team Collaboration
# Compliance Assurance
# Design Reviews
# Manufacturing Support
# Documentation ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.6525235)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.70127994)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6836057)}]
# -----------------------------------------------------
#
# ================ Resume #92 ================
# Design Review
# Coordination
# Proposal Preparation
# Feasibility Analysis
# Software Utilization
# Supervision
# Technical Support
# Submission Review
# Progress Reporting
# Compliance
# Site Visits ...
#
# [{'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6052581)}, {'jd_index': 231, 'job_title': 'Validation Specialist - Cleaning - CIP', 'location_cleaned': 'Rensselaer , NY', 'similarity': np.float32(0.7258356)}, {'jd_index': 486, 'job_title': 'Research Associate (Microbe Screening)', 'location_cleaned': 'Emeryville, CA', 'similarity': np.float32(0.5753208)}]
# -----------------------------------------------------
#
# ================ Resume #93 ================
# Machine Learning Design
# Data Analysis
# Model Training
# AI Integration
# Innovation
# Cross-Functional Collaboration
# Model Deployment
# Documentation
# Analytical Skills
# Communication
# Team Collaboration ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.734273)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6881881)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.66539025)}]
# -----------------------------------------------------
#
# ================ Resume #94 ================
# Management Trainee
# Mechanical Systems
# Maintenance & Troubleshooting
# Performance Analysis
# Project Support
# Process Improvement
# Training & Development
# Administrative Support ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.65698504)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.5765366)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.592489)}]
# -----------------------------------------------------
#
# ================ Resume #95 ================
# Supervision
# Monitoring
# Construction
# Estimation
# Planning
# Material Management
# Project Coordination
# Quality Assurance
# Cost Control
# Inventory
# Operations
# Safety
# Error Escalation
# Miscellaneous Tasks
#
#
#
#
#  ...
#
# [{'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.623536)}, {'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.67971563)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.68842804)}]
# -----------------------------------------------------
#
# ================ Resume #96 ================
# Machinery Maintenance
# Troubleshooting
# Report Preparation
# Log Maintenance ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.7325386)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.6851089)}, {'jd_index': 884, 'job_title': 'Scrum Master', 'location_cleaned': 'Framingham, MA', 'similarity': np.float32(0.59457123)}]
# -----------------------------------------------------
#
# ================ Resume #97 ================
# Machine Learning Leadership
# Cross-Functional Collaboration
# Strategy Development
# ML/NLP Infrastructure
# Prototype Transformation
# ML System Design
# Algorithm Research
# Application Development
# Dataset Selection
# ML Testing
# Statistical Analysis
# R&D in ML/NLP
# Text Representation
# Data Pipeline Design
# Statistical Data Analysis
# Model Training
# Team Collaboration
# Research Reporting
# Algorithm Analysis ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.6362922)}, {'jd_index': 944, 'job_title': 'Principal System Engineer (Big Data)', 'location_cleaned': 'Plano, TX', 'similarity': np.float32(0.60345286)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.5914066)}]
# -----------------------------------------------------
#
# ================ Resume #98 ================
# Data Platform Design
# Data Pipeline Development
# ETL Processes
# SQL Query Optimization
# Data Integration & Transformation
# Data Modeling
# Stakeholder Collaboration
# Data Quality Monitoring
# Continuous Learning ...
#
# [{'jd_index': 1209, 'job_title': 'Lead Accountant', 'location_cleaned': 'Cincinnati, OH', 'similarity': np.float32(0.78941715)}, {'jd_index': 238, 'job_title': 'AVP Finance', 'location_cleaned': 'Kettering, OH', 'similarity': np.float32(0.75155103)}, {'jd_index': 1037, 'job_title': 'Senior Accountant', 'location_cleaned': 'Irving, TX', 'similarity': np.float32(0.64196897)}]
# -----------------------------------------------------
#
# ================ Resume #99 ================
# Administrative Support
# Scheduling
# Filing & Documentation
# Communication
# Team Support
# Equipment Maintenance
# Information Provision
# Inventory Management
# Team Collaboration
# OHS Policy Development
# Safety Advice
# Risk Assessment
# Policy Review
# OHS Training
# Safety Inspections
# Unsafe Act Prevention
# Incident Investigation
# Report Preparation ...
#
# [{'jd_index': 960, 'job_title': 'Software Engineer', 'location_cleaned': 'Tulsa, OK', 'similarity': np.float32(0.64366615)}, {'jd_index': 1199, 'job_title': 'Recruiter', 'location_cleaned': 'Camden, NJ', 'similarity': np.float32(0.64892083)}, {'jd_index': 213, 'job_title': 'Product Manager', 'location_cleaned': 'Durham, NC', 'similarity': np.float32(0.6743766)}]
# -----------------------------------------------------

# %%
output_rows = []

for i in range(len(resume_df)):
    row = resume_df.iloc[i]
    topn = match_resume(row, jd_df, k_coarse=50, k_final=3)  

    while len(topn) < 3:
        topn.append({
            "jd_index": np.nan,
            "job_title": "",
            "location_cleaned": "",
            "similarity": np.nan
        })

    output_rows.append({
        "resume_index": row["resume_index"],
        "resume_career_objective": row.get("career_objective", ""),
        "resume_skills": row.get("skills", ""),
        "resume_degree_names": row.get("degree_names", ""),
        "resume_major_field_of_studies": row.get("major_field_of_studies", ""),
        "resume_responsibilities": row.get("responsibilities", ""),

        "top1_jd_index": topn[0]["jd_index"],
        "top1_similarity": topn[0]["similarity"],
        "top1_job_title": topn[0]["job_title"],
        "top1_location_cleaned": topn[0]["location_cleaned"],

        "top2_jd_index": topn[1]["jd_index"],
        "top2_similarity": topn[1]["similarity"],
        "top2_job_title": topn[1]["job_title"],
        "top2_location_cleaned": topn[1]["location_cleaned"],

        "top3_jd_index": topn[2]["jd_index"],
        "top3_similarity": topn[2]["similarity"],
        "top3_job_title": topn[2]["job_title"],
        "top3_location_cleaned": topn[2]["location_cleaned"],
    })

cross_df = pd.DataFrame(output_rows)

# %%
cross_df.head()
# Out:
#    resume_index                            resume_career_objective  \
# 0             0  Experienced product development Engineer and m...
# 1             1  I am a software engineer, and I want to work o...
# 2             2  I desire to work for a company that provides c...
# 3             3  As a Data Analyst I always look into more inno...
# 4             4  Financial and Accounting professional with exp...
#
#                                        resume_skills  \
# 0  ['Microsoft Office', 'Microsoft Project', 'Pro...
# 1  ['C++', 'Python', 'Firebase', 'Flutter', 'Tens...
# 2  ['Word', 'SAP Time Approval', 'Excel', 'Travel...
# 3  ['Machine Learning', 'Artificial Intelligence'...
# 4  ['Power User of Microsoft Excel Epicor NetSuit...
#
#                        resume_degree_names  resume_major_field_of_studies  \
# 0                  ['Bachelor of Science']     ['Mechanical Engineering']
# 1                               ['B.Tech']                  ['Computers']
# 2                    ['Associate of Arts']  ['Administrative Assistance']
# 3                     ['B.Tech', 'M.Tech']                   [None, None]
# 4  ['Bachelor of Business Administration']                 ['Accounting']
#
#                              resume_responsibilities  top1_jd_index  \
# 0  Management Trainee\nMechanical Systems\nMainte...           1159
# 1  Recruitment Coordination\nAppointment Manageme...            960
# 2  Machine Learning Design\nData Analysis\nModel ...            960
# 3  Mikrotik Router Configuration\nOLT Device Setu...            944
# 4  Design Creation\nCAD Drawings\nDesign Optimiza...           1159
#
#    top1_similarity                        top1_job_title  \
# 0         0.790168                  Sr. Project Engineer
# 1         0.696385                     Software Engineer
# 2         0.693410                     Software Engineer
# 3         0.699035  Principal System Engineer (Big Data)
# 4         0.676850                  Sr. Project Engineer
#
#   top1_location_cleaned  top2_jd_index  top2_similarity  \
# 0     State College, PA            887         0.688563
# 1             Tulsa, OK           1199         0.667130
# 2             Tulsa, OK            213         0.604357
# 3             Plano, TX             65         0.685590
# 4     State College, PA           1209         0.732748
#
#                               top2_job_title top2_location_cleaned  \
# 0                            Product Manager            Boston, MA
# 1                                  Recruiter            Camden, NJ
# 2                            Product Manager            Durham, NC
# 3  IT - Systems Analysis Consultant - Senior      Eden Prairie, MN
# 4                            Lead Accountant        Cincinnati, OH
#
#    top3_jd_index  top3_similarity                    top3_job_title  \
# 0            878         0.674320                   Product Analyst
# 1            395         0.594794  Software Engineer L (Government)
# 2           1199         0.677082                         Recruiter
# 3            960         0.657553                 Software Engineer
# 4             21         0.677297                   Payroll Analyst
#
#   top3_location_cleaned
# 0            Boston, MA
# 1          Columbia, MD
# 2            Camden, NJ
# 3             Tulsa, OK
# 4          Portland, OR

# %%
# create a visualization of the cross encoder similarity scores
import matplotlib.pyplot as plt

# %%
# visualizing the similarity scores of the FTSBert-CE model
fig, axes = plt.subplots(1, 3, figsize=(14, 5))

# A helper function for smart plotting
def smart_hist(ax, data, color, title):
    unique_vals = np.unique(data)
    
    if len(unique_vals) == 1:
        # All values are identical → plot a visible bar
        val = unique_vals[0]
        count = len(data)
        ax.bar([val], [count], width=0.01, color=color, edgecolor='black')
        ax.set_xlim(val - 0.05, val + 0.05)  # zoom in around the bar
        ax.set_title(title)
        ax.set_xlabel('Similarity Score')
        ax.set_ylabel('Frequency')
    else:
        # Normal histogram
        ax.hist(data, bins=30, alpha=0.7, color=color, edgecolor='black')
        ax.set_xlim(0, 1)
        ax.set_title(title)
        ax.set_xlabel('Similarity Score')
        ax.set_ylabel('Frequency')


# Top 1
ce_top1_sims = cross_df['top1_similarity']
smart_hist(
    axes[0],
    ce_top1_sims,
    color='blue',
    title=f'SBert-CE Model - Top 1 Similarity Score\nMean: {ce_top1_sims.mean():.4f}'
)

# Top 2
ce_top2_sims = cross_df['top2_similarity']
smart_hist(
    axes[1],
    ce_top2_sims,
    color='green',
    title=f'SBert-CE Model - Top 2 Similarity Score\nMean: {ce_top2_sims.mean():.4f}'
)

# Top 3
ce_top3_sims = cross_df['top3_similarity']
smart_hist(
    axes[2],
    ce_top3_sims,
    color='red',
    title=f'SBert-CE Model - Top 3 Similarity Score\nMean: {ce_top3_sims.mean():.4f}'
)

plt.tight_layout()
plt.show()

# %%
cross_df.to_csv("../4_model_outputs/crossencoder_outputs.csv")
